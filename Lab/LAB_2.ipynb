# %% [markdown]
# <a href="https://colab.research.google.com/github/ARNAB01-DS/CSE475/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.mixture import GaussianMixture

# %%
df = pd.read_csv('synthetic_mall_customers.csv')

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-639d917b-2157-42bf-b10d-9cfa81fff4b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-639d917b-2157-42bf-b10d-9cfa81fff4b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Select features

# %%
df = pd.read_csv('synthetic_mall_customers.csv')
X = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

# %% [markdown]
# Scale the data (important for DBSCAN and GMM):

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 2. K-Means Clustering

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans_labels = kmeans.fit_predict(X_scaled)

# %% [markdown]
# 3. DBSCAN Clustering

# %%
dbscan = DBSCAN(eps=0.9, min_samples=5)
dbscan_labels = dbscan.fit_predict(X_scaled)

# %% [markdown]
# 4. Gaussian Mixture Model (GMM)

# %%
gmm = GaussianMixture(n_components=5, random_state=42)
gmm_labels = gmm.fit_predict(X_scaled)

# %% [markdown]
# 5.PCA for Visualization (2D)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# 6. Visualization

# %% [markdown]
# K-Means

# %%
plt.figure(figsize=(6,5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, cmap='viridis')
plt.title("K-Means Clustering (PCA)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# DBSCAN

# %%
plt.figure(figsize=(6,5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=gmm_labels, cmap='plasma')
plt.title("GMM Clustering (PCA)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# GMM

# %%
plt.figure(figsize=(6,5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=gmm_labels, cmap='plasma')
plt.title("GMM Clustering (PCA)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
